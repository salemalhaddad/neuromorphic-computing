# %% [markdown]
# Initial notes and questions:
# - What is abolsute intensity information?
# - DVS circuit vs. APS circuit
# - Improvements from DVS-128-15: Dynamic range increase bt 10 db, 80% lower latency, addition of global shutter frames, smaller pixels / higher resolution
# - Tradeoffs vs. DVS-128-15: Worse threshold mismatch (-> limits threshold settings), 0.5 fixed pattern noise
